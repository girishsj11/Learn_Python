# %%
s = "First Program - Python print function\nIt is declared like this : \nprint('what to print')"
print(s)
# Out:
# First Program - Python print function
# It is declared like this :
# print('what to print')

# %%
user_name = input("Enter your name - ")
user_age = int(input("Enter your age - "))
num1 = int(input("Enter 1st number - "))
num2 = float(input("Enter 2nd number - "))
print(f"addition of two numbers - {num1+num2}")
# Out:
# addition of two numbers - 25.5

# %%
print(f"Hey ! {input('Whats your name : ')} ,How are you? ")
# Out:
# Hey ! Giri ,How are you?

# %%
from sys import stderr as err
for i in range(5):
    print(i,i+1,sep=',',end='\n',flush=True,file=err)
# Out:
# 0,1
# 1,2
# 2,3
# 3,4
# 4,5
